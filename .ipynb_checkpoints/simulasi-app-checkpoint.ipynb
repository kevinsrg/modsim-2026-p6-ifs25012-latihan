# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def run_simulation(n_students, min_dur, max_dur, seed=42):
    np.random.seed(seed)
    
    durations = np.random.uniform(min_dur, max_dur, n_students)
    
    events = []
    current_time = 0
    
    for i in range(n_students):
        start = current_time
        duration = durations[i]
        end = start + duration
        wait = start
        
        events.append({
            "mahasiswa": i+1,
            "start_service": start,
            "duration": duration,
            "end_service": end,
            "wait_time": wait
        })
        
        current_time = end
    
    total_time = current_time
    avg_wait = np.mean([e["wait_time"] for e in events])
    utilization = (sum(durations) / total_time) * 100 if total_time > 0 else 0
    
    return {
        "events": events,
        "total_time": total_time,
        "avg_wait": avg_wait,
        "utilization": utilization,
        "durations": durations
    }

# %%
def theoretical_total(n_students, min_dur, max_dur):
    expected = (min_dur + max_dur) / 2
    return n_students * expected

# %%
n_students = 30
min_dur = 1
max_dur = 3
seed = 42

# %%
result = run_simulation(n_students, min_dur, max_dur, seed)
df = pd.DataFrame(result["events"])
teoritis = theoretical_total(n_students, min_dur, max_dur)

df.head()
# Out:
#    mahasiswa  start_service  duration  end_service  wait_time
# 0          1       0.000000  1.749080     1.749080   0.000000
# 1          2       1.749080  2.901429     4.650509   1.749080
# 2          3       4.650509  2.463988     7.114497   4.650509
# 3          4       7.114497  2.197317     9.311814   7.114497
# 4          5       9.311814  1.312037    10.623851   9.311814

# %%
print("Total Waktu:", round(result["total_time"], 2))
print("Teoritis:", round(teoritis, 2))
print("Rata-rata Tunggu:", round(result["avg_wait"], 2))
print("Utilisasi:", round(result["utilization"], 2), "%")
# Out:
# Total Waktu: 56.32
# Teoritis: 60.0
# Rata-rata Tunggu: 28.15
# Utilisasi: 100.0 %

# %%
fig, ax = plt.subplots(figsize=(10, 6))

for _, row in df.iterrows():
    ax.barh(row["mahasiswa"], row["duration"],
            left=row["start_service"])

ax.axvline(result["total_time"], linestyle="--")
ax.set_xlabel("Waktu")
ax.set_ylabel("Mahasiswa")
ax.set_title("Gantt Chart Pelayanan")

plt.show()

# %%
plt.hist(result["durations"], bins=10)
plt.title("Distribusi Durasi")
plt.xlabel("Durasi")
plt.ylabel("Frekuensi")
plt.show()

# %%
overlap = any(df.iloc[i]["start_service"] < df.iloc[i-1]["end_service"]
              for i in range(1, len(df)))

monoton = df["start_service"].diff().dropna().ge(0).all()

print("Overlap:", overlap)
print("Urutan benar:", monoton)
# Out:
# Overlap: False
# Urutan benar: True

# %%
rep = 200
totals = [run_simulation(n_students, min_dur, max_dur, seed=i)["total_time"]
          for i in range(rep)]

sim_mean = np.mean(totals)
error = abs(sim_mean - teoritis) / teoritis * 100

print("Mean Simulasi:", round(sim_mean, 2))
print("Teoritis:", round(teoritis, 2))
print("Error (%):", round(error, 2))
# Out:
# Mean Simulasi: 59.8
# Teoritis: 60.0
# Error (%): 0.34

# %%
plt.hist(totals, bins=20)
plt.axvline(teoritis, linestyle="--", label="Teoritis")
plt.axvline(sim_mean, linestyle="-", label="Simulasi")
plt.legend()
plt.title("Distribusi Total Waktu")
plt.show()

# %%
n_vals = range(5, 60, 5)
totals_n = [np.mean([run_simulation(n, min_dur, max_dur, seed=i)["total_time"]
                     for i in range(50)]) for n in n_vals]

teo_n = [theoretical_total(n, min_dur, max_dur) for n in n_vals]

plt.plot(n_vals, totals_n, 'o-', label="Simulasi")
plt.plot(n_vals, teo_n, 's--', label="Teoritis")
plt.legend()
plt.xlabel("Jumlah Mahasiswa")
plt.ylabel("Total Waktu")
plt.title("Pengaruh N")
plt.show()

# %%
print("Model sudah:")
print("- Terverifikasi (tidak ada overlap, FIFO)")
print("- Tervalidasi (mendekati nilai teoritis)")
print("- Konsisten terhadap perubahan jumlah mahasiswa")
# Out:
# Model sudah:
# - Terverifikasi (tidak ada overlap, FIFO)
# - Tervalidasi (mendekati nilai teoritis)
# - Konsisten terhadap perubahan jumlah mahasiswa
